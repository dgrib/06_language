# %% [markdown]
# # Neural machine translation

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2022-08-03 06:21:41--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14819554 (14M) [application/zip]
# Saving to: ‘rus-eng.zip’
#
# rus-eng.zip         100%[===================>]  14.13M  41.1MB/s    in 0.3s
#
# 2022-08-03 06:21:42 (41.1 MB/s) - ‘rus-eng.zip’ saved [14819554/14819554]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# Archive:  rus-eng.zip
#   inflating: rus-eng/rus.txt
#   inflating: rus-eng/_about.txt

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 71M
# drwxr-xr-x 2 root root 4.0K Aug  3 06:21 .
# drwxr-xr-x 1 root root 4.0K Aug  3 06:21 ..
# -rw-r--r-- 1 root root 1.5K May  2 01:29 _about.txt
# -rw-r--r-- 1 root root  71M May  2 01:29 rus.txt

# %%
# Download the file
path_to_file = "rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[20])
print(ru[20])
# Out:
# <start> duck ! <end>
# <start> пригнись ! <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (444587, 444587)

# %%
# Try experimenting with the size of that dataset
num_examples = 300000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 240000 240000 60000 60000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 9 ----> это
# 13006 ----> типично
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 85 ----> that's
# 2549 ----> typical
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 200
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 18]), TensorShape([64, 14]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, hidden):
    # enc_output shape == (batch_size, max_length, hidden_size)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x, initial_state=hidden)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 12605])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0)) # маска будет зануляиь нулевые токены паддинга , 
            #через которые мы не хотим прокидывать градиент, 
            #поэтому мы их сразу в лоссе зануляем чтобы они на лосс никак не реагировали, 
            #чтобы не вносили джобавочные коэффициенты в наш лосс
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
# %%time

EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)): 
        # inp это текст на русском а targ это текст на англ - то что мы ходим получить
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.6892
# Epoch 1 Batch 100 Loss 2.2355
# Epoch 1 Batch 200 Loss 1.9385
# Epoch 1 Batch 300 Loss 1.8131
# Epoch 1 Batch 400 Loss 1.7556
# Epoch 1 Batch 500 Loss 1.6755
# Epoch 1 Batch 600 Loss 1.6880
# Epoch 1 Batch 700 Loss 1.5366
# Epoch 1 Batch 800 Loss 1.6738
# Epoch 1 Batch 900 Loss 1.4137
# Epoch 1 Batch 1000 Loss 1.2655
# Epoch 1 Batch 1100 Loss 1.3175
# Epoch 1 Batch 1200 Loss 1.3982
# Epoch 1 Batch 1300 Loss 1.1530
# Epoch 1 Batch 1400 Loss 1.2634
# Epoch 1 Batch 1500 Loss 1.1518
# Epoch 1 Batch 1600 Loss 1.0954
# Epoch 1 Batch 1700 Loss 1.1171
# Epoch 1 Batch 1800 Loss 1.0170
# Epoch 1 Batch 1900 Loss 0.9484
# Epoch 1 Batch 2000 Loss 0.9553
# Epoch 1 Batch 2100 Loss 0.8893
# Epoch 1 Batch 2200 Loss 0.9847
# Epoch 1 Batch 2300 Loss 0.9165
# Epoch 1 Batch 2400 Loss 0.9137
# Epoch 1 Batch 2500 Loss 0.9785
# Epoch 1 Batch 2600 Loss 0.8960
# Epoch 1 Batch 2700 Loss 0.7773
# Epoch 1 Batch 2800 Loss 0.7177
# Epoch 1 Batch 2900 Loss 0.7743
# Epoch 1 Batch 3000 Loss 0.7787
# Epoch 1 Batch 3100 Loss 0.7220
# Epoch 1 Batch 3200 Loss 0.8330
# Epoch 1 Batch 3300 Loss 0.7134
# Epoch 1 Batch 3400 Loss 0.7198
# Epoch 1 Batch 3500 Loss 0.5367
# Epoch 1 Batch 3600 Loss 0.6651
# Epoch 1 Batch 3700 Loss 0.5153
# Epoch 1 Loss 1.1569
# Time taken for 1 epoch 1262.966825723648 sec
#
# Epoch 2 Batch 0 Loss 0.6193
# Epoch 2 Batch 100 Loss 0.6710
# Epoch 2 Batch 200 Loss 0.5507
# Epoch 2 Batch 300 Loss 0.5431
# Epoch 2 Batch 400 Loss 0.4993
# Epoch 2 Batch 500 Loss 0.5121
# Epoch 2 Batch 600 Loss 0.5252
# Epoch 2 Batch 700 Loss 0.5458
# Epoch 2 Batch 800 Loss 0.4823
# Epoch 2 Batch 900 Loss 0.4687
# Epoch 2 Batch 1000 Loss 0.4889
# Epoch 2 Batch 1100 Loss 0.4659
# Epoch 2 Batch 1200 Loss 0.5925
# Epoch 2 Batch 1300 Loss 0.5070
# Epoch 2 Batch 1400 Loss 0.3941
# Epoch 2 Batch 1500 Loss 0.4363
# Epoch 2 Batch 1600 Loss 0.4531
# Epoch 2 Batch 1700 Loss 0.4544
# Epoch 2 Batch 1800 Loss 0.4392
# Epoch 2 Batch 1900 Loss 0.4787
# Epoch 2 Batch 2000 Loss 0.4073
# Epoch 2 Batch 2100 Loss 0.5037
# Epoch 2 Batch 2200 Loss 0.4121
# Epoch 2 Batch 2300 Loss 0.3691
# Epoch 2 Batch 2400 Loss 0.5078
# Epoch 2 Batch 2500 Loss 0.3097
# Epoch 2 Batch 2600 Loss 0.3683
# Epoch 2 Batch 2700 Loss 0.3564
# Epoch 2 Batch 2800 Loss 0.3041
# Epoch 2 Batch 2900 Loss 0.4559
# Epoch 2 Batch 3000 Loss 0.4121
# Epoch 2 Batch 3100 Loss 0.4652
# Epoch 2 Batch 3200 Loss 0.4469
# Epoch 2 Batch 3300 Loss 0.3397
# Epoch 2 Batch 3400 Loss 0.3384
# Epoch 2 Batch 3500 Loss 0.3972
# Epoch 2 Batch 3600 Loss 0.4079
# Epoch 2 Batch 3700 Loss 0.3753
# Epoch 2 Loss 0.4592
# Time taken for 1 epoch 1244.0629479885101 sec
#
# Epoch 3 Batch 0 Loss 0.2751
# Epoch 3 Batch 100 Loss 0.2777
# Epoch 3 Batch 200 Loss 0.2885
# Epoch 3 Batch 300 Loss 0.2016
# Epoch 3 Batch 400 Loss 0.2485
# Epoch 3 Batch 500 Loss 0.2839
# Epoch 3 Batch 600 Loss 0.2788
# Epoch 3 Batch 700 Loss 0.2362
# Epoch 3 Batch 800 Loss 0.2638
# Epoch 3 Batch 900 Loss 0.2658
# Epoch 3 Batch 1000 Loss 0.2666
# Epoch 3 Batch 1100 Loss 0.3762
# Epoch 3 Batch 1200 Loss 0.2303
# Epoch 3 Batch 1300 Loss 0.2472
# Epoch 3 Batch 1400 Loss 0.3304
# Epoch 3 Batch 1500 Loss 0.3169
# Epoch 3 Batch 1600 Loss 0.3078
# Epoch 3 Batch 1700 Loss 0.3326
# Epoch 3 Batch 1800 Loss 0.2653
# Epoch 3 Batch 1900 Loss 0.3429
# Epoch 3 Batch 2000 Loss 0.2003
# Epoch 3 Batch 2100 Loss 0.3185
# Epoch 3 Batch 2200 Loss 0.2948
# Epoch 3 Batch 2300 Loss 0.1798
# Epoch 3 Batch 2400 Loss 0.2852
# Epoch 3 Batch 2500 Loss 0.2962
# Epoch 3 Batch 2600 Loss 0.2371
# Epoch 3 Batch 2700 Loss 0.2473
# Epoch 3 Batch 2800 Loss 0.3387
# Epoch 3 Batch 2900 Loss 0.2769
# Epoch 3 Batch 3000 Loss 0.3108
# Epoch 3 Batch 3100 Loss 0.2883
# Epoch 3 Batch 3200 Loss 0.3115
# Epoch 3 Batch 3300 Loss 0.2762
# Epoch 3 Batch 3400 Loss 0.2839
# Epoch 3 Batch 3500 Loss 0.2975
# Epoch 3 Batch 3600 Loss 0.3033
# Epoch 3 Batch 3700 Loss 0.3009
# Epoch 3 Loss 0.2747
# Time taken for 1 epoch 1221.295469045639 sec
#
# Epoch 4 Batch 0 Loss 0.1363
# Epoch 4 Batch 100 Loss 0.1886
# Epoch 4 Batch 200 Loss 0.2187
# Epoch 4 Batch 300 Loss 0.2003
# Epoch 4 Batch 400 Loss 0.1795
# Epoch 4 Batch 500 Loss 0.1870
# Epoch 4 Batch 600 Loss 0.1696
# Epoch 4 Batch 700 Loss 0.2120
# Epoch 4 Batch 800 Loss 0.1476
# Epoch 4 Batch 900 Loss 0.1997
# Epoch 4 Batch 1000 Loss 0.1925
# Epoch 4 Batch 1100 Loss 0.1534
# Epoch 4 Batch 1200 Loss 0.1879
# Epoch 4 Batch 1300 Loss 0.2159
# Epoch 4 Batch 1400 Loss 0.1757
# Epoch 4 Batch 1500 Loss 0.1616
# Epoch 4 Batch 1600 Loss 0.2409
# Epoch 4 Batch 1700 Loss 0.1691
# Epoch 4 Batch 1800 Loss 0.1945
# Epoch 4 Batch 1900 Loss 0.2525
# Epoch 4 Batch 2000 Loss 0.2275
# Epoch 4 Batch 2100 Loss 0.1936
# Epoch 4 Batch 2200 Loss 0.1837
# Epoch 4 Batch 2300 Loss 0.1985
# Epoch 4 Batch 2400 Loss 0.1960
# Epoch 4 Batch 2500 Loss 0.1969
# Epoch 4 Batch 2600 Loss 0.1648
# Epoch 4 Batch 2700 Loss 0.2047
# Epoch 4 Batch 2800 Loss 0.2211
# Epoch 4 Batch 2900 Loss 0.1686
# Epoch 4 Batch 3000 Loss 0.1815
# Epoch 4 Batch 3100 Loss 0.2412
# Epoch 4 Batch 3200 Loss 0.2074
# Epoch 4 Batch 3300 Loss 0.1673
# Epoch 4 Batch 3400 Loss 0.1795
# Epoch 4 Batch 3500 Loss 0.1464
# Epoch 4 Batch 3600 Loss 0.1613
# Epoch 4 Batch 3700 Loss 0.2125
# Epoch 4 Loss 0.1948
# Time taken for 1 epoch 1248.3130323886871 sec
#
# Epoch 5 Batch 0 Loss 0.1037
# Epoch 5 Batch 100 Loss 0.1219
# Epoch 5 Batch 200 Loss 0.1077
# Epoch 5 Batch 300 Loss 0.1710
# Epoch 5 Batch 400 Loss 0.0957
# Epoch 5 Batch 500 Loss 0.1753
# Epoch 5 Batch 600 Loss 0.1258
# Epoch 5 Batch 700 Loss 0.1405
# Epoch 5 Batch 800 Loss 0.1375
# Epoch 5 Batch 900 Loss 0.1220
# Epoch 5 Batch 1000 Loss 0.1283
# Epoch 5 Batch 1100 Loss 0.1358
# Epoch 5 Batch 1200 Loss 0.1655
# Epoch 5 Batch 1300 Loss 0.1792
# Epoch 5 Batch 1400 Loss 0.1169
# Epoch 5 Batch 1500 Loss 0.1181
# Epoch 5 Batch 1600 Loss 0.1254
# Epoch 5 Batch 1700 Loss 0.1616
# Epoch 5 Batch 1800 Loss 0.1341
# Epoch 5 Batch 1900 Loss 0.1544
# Epoch 5 Batch 2000 Loss 0.1569
# Epoch 5 Batch 2100 Loss 0.1759
# Epoch 5 Batch 2200 Loss 0.1934
# Epoch 5 Batch 2300 Loss 0.1446
# Epoch 5 Batch 2400 Loss 0.1745
# Epoch 5 Batch 2500 Loss 0.1723
# Epoch 5 Batch 2600 Loss 0.1595
# Epoch 5 Batch 2700 Loss 0.1845
# Epoch 5 Batch 2800 Loss 0.1482
# Epoch 5 Batch 2900 Loss 0.1473
# Epoch 5 Batch 3000 Loss 0.2419
# Epoch 5 Batch 3100 Loss 0.1970
# Epoch 5 Batch 3200 Loss 0.1266
# Epoch 5 Batch 3300 Loss 0.1767
# Epoch 5 Batch 3400 Loss 0.1833
# Epoch 5 Batch 3500 Loss 0.1822
# Epoch 5 Batch 3600 Loss 0.1856
# Epoch 5 Batch 3700 Loss 0.2076
# Epoch 5 Loss 0.1554
# Time taken for 1 epoch 1265.8616461753845 sec
#
# Epoch 6 Batch 0 Loss 0.1588
# Epoch 6 Batch 100 Loss 0.0986
# Epoch 6 Batch 200 Loss 0.0756
# Epoch 6 Batch 300 Loss 0.1008
# Epoch 6 Batch 400 Loss 0.1123
# Epoch 6 Batch 500 Loss 0.1503
# Epoch 6 Batch 600 Loss 0.1382
# Epoch 6 Batch 700 Loss 0.1248
# Epoch 6 Batch 800 Loss 0.1021
# Epoch 6 Batch 900 Loss 0.1320
# Epoch 6 Batch 1000 Loss 0.1211
# Epoch 6 Batch 1100 Loss 0.1150
# Epoch 6 Batch 1200 Loss 0.1750
# Epoch 6 Batch 1300 Loss 0.0917
# Epoch 6 Batch 1400 Loss 0.1250
# Epoch 6 Batch 1500 Loss 0.1515
# Epoch 6 Batch 1600 Loss 0.1409
# Epoch 6 Batch 1700 Loss 0.1261
# Epoch 6 Batch 1800 Loss 0.1112
# Epoch 6 Batch 1900 Loss 0.1322
# Epoch 6 Batch 2000 Loss 0.1025
# Epoch 6 Batch 2100 Loss 0.1437
# Epoch 6 Batch 2200 Loss 0.1556
# Epoch 6 Batch 2300 Loss 0.1432
# Epoch 6 Batch 2400 Loss 0.1569
# Epoch 6 Batch 2500 Loss 0.1648
# Epoch 6 Batch 2600 Loss 0.1183
# Epoch 6 Batch 2700 Loss 0.1546
# Epoch 6 Batch 2800 Loss 0.1276
# Epoch 6 Batch 2900 Loss 0.1581
# Epoch 6 Batch 3000 Loss 0.1611
# Epoch 6 Batch 3100 Loss 0.1123
# Epoch 6 Batch 3200 Loss 0.1789
# Epoch 6 Batch 3300 Loss 0.1446
# Epoch 6 Batch 3400 Loss 0.1496
# Epoch 6 Batch 3500 Loss 0.1391
# Epoch 6 Batch 3600 Loss 0.1824
# Epoch 6 Batch 3700 Loss 0.1570
# Epoch 6 Loss 0.1342
# Time taken for 1 epoch 1255.1900165081024 sec
#
# Epoch 7 Batch 0 Loss 0.1109
# Epoch 7 Batch 100 Loss 0.1064
# Epoch 7 Batch 200 Loss 0.0750
# Epoch 7 Batch 300 Loss 0.1217
# Epoch 7 Batch 400 Loss 0.1049
# Epoch 7 Batch 500 Loss 0.1052
# Epoch 7 Batch 600 Loss 0.1169
# Epoch 7 Batch 700 Loss 0.0961
# Epoch 7 Batch 800 Loss 0.0932
# Epoch 7 Batch 900 Loss 0.1017
# Epoch 7 Batch 1000 Loss 0.1098
# Epoch 7 Batch 1100 Loss 0.0871
# Epoch 7 Batch 1200 Loss 0.1026
# Epoch 7 Batch 1300 Loss 0.0993
# Epoch 7 Batch 1400 Loss 0.1190
# Epoch 7 Batch 1500 Loss 0.1266
# Epoch 7 Batch 1600 Loss 0.1106
# Epoch 7 Batch 1700 Loss 0.1175
# Epoch 7 Batch 1800 Loss 0.1294
# Epoch 7 Batch 1900 Loss 0.1090
# Epoch 7 Batch 2000 Loss 0.1204
# Epoch 7 Batch 2100 Loss 0.0878
# Epoch 7 Batch 2200 Loss 0.1384
# Epoch 7 Batch 2300 Loss 0.0999
# Epoch 7 Batch 2400 Loss 0.1460
# Epoch 7 Batch 2500 Loss 0.1161
# Epoch 7 Batch 2600 Loss 0.1254
# Epoch 7 Batch 2700 Loss 0.1250
# Epoch 7 Batch 2800 Loss 0.1231
# Epoch 7 Batch 2900 Loss 0.1438
# Epoch 7 Batch 3000 Loss 0.1455
# Epoch 7 Batch 3100 Loss 0.1234
# Epoch 7 Batch 3200 Loss 0.1058
# Epoch 7 Batch 3300 Loss 0.1519
# Epoch 7 Batch 3400 Loss 0.1833
# Epoch 7 Batch 3500 Loss 0.1765
# Epoch 7 Batch 3600 Loss 0.1616
# Epoch 7 Batch 3700 Loss 0.1156
# Epoch 7 Loss 0.1215
# Time taken for 1 epoch 1217.4793915748596 sec
#
# Epoch 8 Batch 0 Loss 0.0892
# Epoch 8 Batch 100 Loss 0.0728
# Epoch 8 Batch 200 Loss 0.0839
# Epoch 8 Batch 300 Loss 0.0750
# Epoch 8 Batch 400 Loss 0.0873
# Epoch 8 Batch 500 Loss 0.0856
# Epoch 8 Batch 600 Loss 0.0966
# Epoch 8 Batch 700 Loss 0.1046
# Epoch 8 Batch 800 Loss 0.0898
# Epoch 8 Batch 900 Loss 0.1068
# Epoch 8 Batch 1000 Loss 0.1281
# Epoch 8 Batch 1100 Loss 0.1025
# Epoch 8 Batch 1200 Loss 0.1248
# Epoch 8 Batch 1300 Loss 0.1023
# Epoch 8 Batch 1400 Loss 0.1045
# Epoch 8 Batch 1500 Loss 0.1002
# Epoch 8 Batch 1600 Loss 0.1132
# Epoch 8 Batch 1700 Loss 0.0972
# Epoch 8 Batch 1800 Loss 0.0827
# Epoch 8 Batch 1900 Loss 0.1594
# Epoch 8 Batch 2000 Loss 0.1338
# Epoch 8 Batch 2100 Loss 0.1201
# Epoch 8 Batch 2200 Loss 0.0977
# Epoch 8 Batch 2300 Loss 0.1722
# Epoch 8 Batch 2400 Loss 0.1011
# Epoch 8 Batch 2500 Loss 0.1215
# Epoch 8 Batch 2600 Loss 0.1012
# Epoch 8 Batch 2700 Loss 0.0879
# Epoch 8 Batch 2800 Loss 0.1561
# Epoch 8 Batch 2900 Loss 0.1246
# Epoch 8 Batch 3000 Loss 0.1547
# Epoch 8 Batch 3100 Loss 0.1288
# Epoch 8 Batch 3200 Loss 0.1136
# Epoch 8 Batch 3300 Loss 0.1038
# Epoch 8 Batch 3400 Loss 0.1536
# Epoch 8 Batch 3500 Loss 0.1588
# Epoch 8 Batch 3600 Loss 0.1369
# Epoch 8 Batch 3700 Loss 0.1499
# Epoch 8 Loss 0.1145
# Time taken for 1 epoch 1253.735238790512 sec
#
# Epoch 9 Batch 0 Loss 0.1106
# Epoch 9 Batch 100 Loss 0.0864
# Epoch 9 Batch 200 Loss 0.0997
# Epoch 9 Batch 300 Loss 0.0548
# Epoch 9 Batch 400 Loss 0.0917
# Epoch 9 Batch 500 Loss 0.1022
# Epoch 9 Batch 600 Loss 0.1015
# Epoch 9 Batch 700 Loss 0.0793
# Epoch 9 Batch 800 Loss 0.1210
# Epoch 9 Batch 900 Loss 0.1339
# Epoch 9 Batch 1000 Loss 0.0957
# Epoch 9 Batch 1100 Loss 0.0624
# Epoch 9 Batch 1200 Loss 0.0837
# Epoch 9 Batch 1300 Loss 0.0949
# Epoch 9 Batch 1400 Loss 0.1147
# Epoch 9 Batch 1500 Loss 0.0849
# Epoch 9 Batch 1600 Loss 0.1229
# Epoch 9 Batch 1700 Loss 0.0956
# Epoch 9 Batch 1800 Loss 0.1446
# Epoch 9 Batch 1900 Loss 0.0809
# Epoch 9 Batch 2000 Loss 0.1007
# Epoch 9 Batch 2100 Loss 0.1084
# Epoch 9 Batch 2200 Loss 0.0825
# Epoch 9 Batch 2300 Loss 0.1081
# Epoch 9 Batch 2400 Loss 0.0885
# Epoch 9 Batch 2500 Loss 0.1304
# Epoch 9 Batch 2600 Loss 0.1162
# Epoch 9 Batch 2700 Loss 0.1266
# Epoch 9 Batch 2800 Loss 0.1273
# Epoch 9 Batch 2900 Loss 0.1147
# Epoch 9 Batch 3000 Loss 0.1262
# Epoch 9 Batch 3100 Loss 0.1259
# Epoch 9 Batch 3200 Loss 0.1014
# Epoch 9 Batch 3300 Loss 0.1197
# Epoch 9 Batch 3400 Loss 0.1205
# Epoch 9 Batch 3500 Loss 0.1035
# Epoch 9 Batch 3600 Loss 0.1344
# Epoch 9 Batch 3700 Loss 0.1510
# Epoch 9 Loss 0.1083
# Time taken for 1 epoch 1277.1381623744965 sec
#
# Epoch 10 Batch 0 Loss 0.0645
# Epoch 10 Batch 100 Loss 0.1105
# Epoch 10 Batch 200 Loss 0.0748
# Epoch 10 Batch 300 Loss 0.0844
# Epoch 10 Batch 400 Loss 0.1098
# Epoch 10 Batch 500 Loss 0.0956
# Epoch 10 Batch 600 Loss 0.0689
# Epoch 10 Batch 700 Loss 0.0843
# Epoch 10 Batch 800 Loss 0.0745
# Epoch 10 Batch 900 Loss 0.0728
# Epoch 10 Batch 1000 Loss 0.1073
# Epoch 10 Batch 1100 Loss 0.0719
# Epoch 10 Batch 1200 Loss 0.0990
# Epoch 10 Batch 1300 Loss 0.1058
# Epoch 10 Batch 1400 Loss 0.1205
# Epoch 10 Batch 1500 Loss 0.1097
# Epoch 10 Batch 1600 Loss 0.1080
# Epoch 10 Batch 1700 Loss 0.1000
# Epoch 10 Batch 1800 Loss 0.1034
# Epoch 10 Batch 1900 Loss 0.1172
# Epoch 10 Batch 2000 Loss 0.0836
# Epoch 10 Batch 2100 Loss 0.0961
# Epoch 10 Batch 2200 Loss 0.0990
# Epoch 10 Batch 2300 Loss 0.1005
# Epoch 10 Batch 2400 Loss 0.1490
# Epoch 10 Batch 2500 Loss 0.1009
# Epoch 10 Batch 2600 Loss 0.1202
# Epoch 10 Batch 2700 Loss 0.1295
# Epoch 10 Batch 2800 Loss 0.1060
# Epoch 10 Batch 2900 Loss 0.1189
# Epoch 10 Batch 3000 Loss 0.1012
# Epoch 10 Batch 3100 Loss 0.0978
# Epoch 10 Batch 3200 Loss 0.1033
# Epoch 10 Batch 3300 Loss 0.1166
# Epoch 10 Batch 3400 Loss 0.1482
# Epoch 10 Batch 3500 Loss 0.1171
# Epoch 10 Batch 3600 Loss 0.1457
# Epoch 10 Batch 3700 Loss 0.1368
# Epoch 10 Loss 0.1049
# Time taken for 1 epoch 1244.1069388389587 sec
#
# Epoch 11 Batch 0 Loss 0.1031
# Epoch 11 Batch 100 Loss 0.0856
# Epoch 11 Batch 200 Loss 0.0784
# Epoch 11 Batch 300 Loss 0.0807
# Epoch 11 Batch 400 Loss 0.0779
# Epoch 11 Batch 500 Loss 0.0762
# Epoch 11 Batch 600 Loss 0.0717
# Epoch 11 Batch 700 Loss 0.0835
# Epoch 11 Batch 800 Loss 0.0872
# Epoch 11 Batch 900 Loss 0.0864
# Epoch 11 Batch 1000 Loss 0.1267
# Epoch 11 Batch 1100 Loss 0.0971
# Epoch 11 Batch 1200 Loss 0.0861
# Epoch 11 Batch 1300 Loss 0.0790
# Epoch 11 Batch 1400 Loss 0.0934
# Epoch 11 Batch 1500 Loss 0.0794
# Epoch 11 Batch 1600 Loss 0.1386
# Epoch 11 Batch 1700 Loss 0.1424
# Epoch 11 Batch 1800 Loss 0.0943
# Epoch 11 Batch 1900 Loss 0.0781
# Epoch 11 Batch 2000 Loss 0.1168
# Epoch 11 Batch 2100 Loss 0.1329
# Epoch 11 Batch 2200 Loss 0.0944
# Epoch 11 Batch 2300 Loss 0.1345
# Epoch 11 Batch 2400 Loss 0.1027
# Epoch 11 Batch 2500 Loss 0.0925
# Epoch 11 Batch 2600 Loss 0.0990
# Epoch 11 Batch 2700 Loss 0.1282
# Epoch 11 Batch 2800 Loss 0.1256
# Epoch 11 Batch 2900 Loss 0.0784
# Epoch 11 Batch 3000 Loss 0.0960
# Epoch 11 Batch 3100 Loss 0.1199
# Epoch 11 Batch 3200 Loss 0.0772
# Epoch 11 Batch 3300 Loss 0.0892
# Epoch 11 Batch 3400 Loss 0.1185
# Epoch 11 Batch 3500 Loss 0.0959
# Epoch 11 Batch 3600 Loss 0.1230
# Epoch 11 Batch 3700 Loss 0.1457
# Epoch 11 Loss 0.1018
# Time taken for 1 epoch 1265.1528854370117 sec
#
# Epoch 12 Batch 0 Loss 0.0682
# Epoch 12 Batch 100 Loss 0.0780
# Epoch 12 Batch 200 Loss 0.0996
# Epoch 12 Batch 300 Loss 0.0710
# Epoch 12 Batch 400 Loss 0.0724
# Epoch 12 Batch 500 Loss 0.1079
# Epoch 12 Batch 600 Loss 0.0587
# Epoch 12 Batch 700 Loss 0.0953
# Epoch 12 Batch 800 Loss 0.0807
# Epoch 12 Batch 900 Loss 0.1166
# Epoch 12 Batch 1000 Loss 0.1055
# Epoch 12 Batch 1100 Loss 0.1063
# Epoch 12 Batch 1200 Loss 0.0516
# Epoch 12 Batch 1300 Loss 0.1056
# Epoch 12 Batch 1400 Loss 0.0988
# Epoch 12 Batch 1500 Loss 0.0995
# Epoch 12 Batch 1600 Loss 0.1021
# Epoch 12 Batch 1700 Loss 0.1043
# Epoch 12 Batch 1800 Loss 0.0906
# Epoch 12 Batch 1900 Loss 0.0960
# Epoch 12 Batch 2000 Loss 0.1169
# Epoch 12 Batch 2100 Loss 0.0912
# Epoch 12 Batch 2200 Loss 0.1154
# Epoch 12 Batch 2300 Loss 0.0880
# Epoch 12 Batch 2400 Loss 0.0911
# Epoch 12 Batch 2500 Loss 0.1021
# Epoch 12 Batch 2600 Loss 0.1708
# Epoch 12 Batch 2700 Loss 0.1581
# Epoch 12 Batch 2800 Loss 0.0916
# Epoch 12 Batch 2900 Loss 0.1027
# Epoch 12 Batch 3000 Loss 0.1165
# Epoch 12 Batch 3100 Loss 0.1372
# Epoch 12 Batch 3200 Loss 0.1073
# Epoch 12 Batch 3300 Loss 0.1088
# Epoch 12 Batch 3400 Loss 0.1373
# Epoch 12 Batch 3500 Loss 0.1208
# Epoch 12 Batch 3600 Loss 0.1296
# Epoch 12 Batch 3700 Loss 0.2038
# Epoch 12 Loss 0.0996
# Time taken for 1 epoch 1238.576434135437 sec
#
# Epoch 13 Batch 0 Loss 0.0635
# Epoch 13 Batch 100 Loss 0.0566
# Epoch 13 Batch 200 Loss 0.0759
# Epoch 13 Batch 300 Loss 0.0555
# Epoch 13 Batch 400 Loss 0.0937
# Epoch 13 Batch 500 Loss 0.1008
# Epoch 13 Batch 600 Loss 0.0957
# Epoch 13 Batch 700 Loss 0.0881
# Epoch 13 Batch 800 Loss 0.0535
# Epoch 13 Batch 900 Loss 0.0790
# Epoch 13 Batch 1000 Loss 0.1058
# Epoch 13 Batch 1100 Loss 0.0763
# Epoch 13 Batch 1200 Loss 0.1215
# Epoch 13 Batch 1300 Loss 0.0413
# Epoch 13 Batch 1400 Loss 0.0882
# Epoch 13 Batch 1500 Loss 0.0442
# Epoch 13 Batch 1600 Loss 0.0997
# Epoch 13 Batch 1700 Loss 0.0784
# Epoch 13 Batch 1800 Loss 0.1065
# Epoch 13 Batch 1900 Loss 0.0993
# Epoch 13 Batch 2000 Loss 0.1404
# Epoch 13 Batch 2100 Loss 0.1200
# Epoch 13 Batch 2200 Loss 0.1173
# Epoch 13 Batch 2300 Loss 0.1273
# Epoch 13 Batch 2400 Loss 0.0943
# Epoch 13 Batch 2500 Loss 0.0945
# Epoch 13 Batch 2600 Loss 0.1214
# Epoch 13 Batch 2700 Loss 0.0903
# Epoch 13 Batch 2800 Loss 0.1279
# Epoch 13 Batch 2900 Loss 0.1331
# Epoch 13 Batch 3000 Loss 0.0639
# Epoch 13 Batch 3100 Loss 0.1039
# Epoch 13 Batch 3200 Loss 0.1020
# Epoch 13 Batch 3300 Loss 0.1147
# Epoch 13 Batch 3400 Loss 0.1101
# Epoch 13 Batch 3500 Loss 0.1501
# Epoch 13 Batch 3600 Loss 0.1142
# Epoch 13 Batch 3700 Loss 0.1182
# Epoch 13 Loss 0.0994
# Time taken for 1 epoch 1248.2928352355957 sec
#
# Epoch 14 Batch 0 Loss 0.0590
# Epoch 14 Batch 100 Loss 0.1159
# Epoch 14 Batch 200 Loss 0.0849
# Epoch 14 Batch 300 Loss 0.0904
# Epoch 14 Batch 400 Loss 0.0674
# Epoch 14 Batch 500 Loss 0.0941
# Epoch 14 Batch 600 Loss 0.0921
# Epoch 14 Batch 700 Loss 0.0947
# Epoch 14 Batch 800 Loss 0.0999
# Epoch 14 Batch 900 Loss 0.0499
# Epoch 14 Batch 1000 Loss 0.0828
# Epoch 14 Batch 1100 Loss 0.0943
# Epoch 14 Batch 1200 Loss 0.0862
# Epoch 14 Batch 1300 Loss 0.1032
# Epoch 14 Batch 1400 Loss 0.0684
# Epoch 14 Batch 1500 Loss 0.1412
# Epoch 14 Batch 1600 Loss 0.0681
# Epoch 14 Batch 1700 Loss 0.0856
# Epoch 14 Batch 1800 Loss 0.1056
# Epoch 14 Batch 1900 Loss 0.0831
# Epoch 14 Batch 2000 Loss 0.1147
# Epoch 14 Batch 2100 Loss 0.0977
# Epoch 14 Batch 2200 Loss 0.0884
# Epoch 14 Batch 2300 Loss 0.1068
# Epoch 14 Batch 2400 Loss 0.0949
# Epoch 14 Batch 2500 Loss 0.0738
# Epoch 14 Batch 2600 Loss 0.0991
# Epoch 14 Batch 2700 Loss 0.0967
# Epoch 14 Batch 2800 Loss 0.1090
# Epoch 14 Batch 2900 Loss 0.0974
# Epoch 14 Batch 3000 Loss 0.1380
# Epoch 14 Batch 3100 Loss 0.1381
# Epoch 14 Batch 3200 Loss 0.1086
# Epoch 14 Batch 3300 Loss 0.0741
# Epoch 14 Batch 3400 Loss 0.0949
# Epoch 14 Batch 3500 Loss 0.1176
# Epoch 14 Batch 3600 Loss 0.1182
# Epoch 14 Batch 3700 Loss 0.1281
# Epoch 14 Loss 0.0972
# Time taken for 1 epoch 1270.1729550361633 sec
#
# Epoch 15 Batch 0 Loss 0.0988
# Epoch 15 Batch 100 Loss 0.0515
# Epoch 15 Batch 200 Loss 0.0755
# Epoch 15 Batch 300 Loss 0.0807
# Epoch 15 Batch 400 Loss 0.1032
# Epoch 15 Batch 500 Loss 0.0950
# Epoch 15 Batch 600 Loss 0.0896
# Epoch 15 Batch 700 Loss 0.0817
# Epoch 15 Batch 800 Loss 0.0711
# Epoch 15 Batch 900 Loss 0.0920
# Epoch 15 Batch 1000 Loss 0.0401
# Epoch 15 Batch 1100 Loss 0.0879
# Epoch 15 Batch 1200 Loss 0.0849
# Epoch 15 Batch 1300 Loss 0.0839
# Epoch 15 Batch 1400 Loss 0.0755
# Epoch 15 Batch 1500 Loss 0.0904
# Epoch 15 Batch 1600 Loss 0.1114
# Epoch 15 Batch 1700 Loss 0.1262
# Epoch 15 Batch 1800 Loss 0.0688
# Epoch 15 Batch 1900 Loss 0.1288
# Epoch 15 Batch 2000 Loss 0.1193
# Epoch 15 Batch 2100 Loss 0.1379
# Epoch 15 Batch 2200 Loss 0.0866
# Epoch 15 Batch 2300 Loss 0.1274
# Epoch 15 Batch 2400 Loss 0.1017
# Epoch 15 Batch 2500 Loss 0.0862
# Epoch 15 Batch 2600 Loss 0.1126
# Epoch 15 Batch 2700 Loss 0.1055
# Epoch 15 Batch 2800 Loss 0.1164
# Epoch 15 Batch 2900 Loss 0.1088
# Epoch 15 Batch 3000 Loss 0.0875
# Epoch 15 Batch 3100 Loss 0.1614
# Epoch 15 Batch 3200 Loss 0.0926
# Epoch 15 Batch 3300 Loss 0.1313
# Epoch 15 Batch 3400 Loss 0.1070
# Epoch 15 Batch 3500 Loss 0.0825
# Epoch 15 Batch 3600 Loss 0.1240
# Epoch 15 Batch 3700 Loss 0.1017
# Epoch 15 Loss 0.0974
# Time taken for 1 epoch 1271.5404093265533 sec
#
# Epoch 16 Batch 0 Loss 0.0801
# Epoch 16 Batch 100 Loss 0.0709
# Epoch 16 Batch 200 Loss 0.0665
# Epoch 16 Batch 300 Loss 0.0729
# Epoch 16 Batch 400 Loss 0.0661
# Epoch 16 Batch 500 Loss 0.0666
# Epoch 16 Batch 600 Loss 0.0787
# Epoch 16 Batch 700 Loss 0.1338
# Epoch 16 Batch 800 Loss 0.0929
# Epoch 16 Batch 900 Loss 0.0742
# Epoch 16 Batch 1000 Loss 0.0621
# Epoch 16 Batch 1100 Loss 0.0664
# Epoch 16 Batch 1200 Loss 0.1036
# Epoch 16 Batch 1300 Loss 0.1061
# Epoch 16 Batch 1400 Loss 0.0867
# Epoch 16 Batch 1500 Loss 0.1036
# Epoch 16 Batch 1600 Loss 0.1255
# Epoch 16 Batch 1700 Loss 0.1062
# Epoch 16 Batch 1800 Loss 0.0893
# Epoch 16 Batch 1900 Loss 0.1350
# Epoch 16 Batch 2000 Loss 0.1089
# Epoch 16 Batch 2100 Loss 0.0601
# Epoch 16 Batch 2200 Loss 0.1497
# Epoch 16 Batch 2300 Loss 0.1083
# Epoch 16 Batch 2400 Loss 0.1063
# Epoch 16 Batch 2500 Loss 0.1001
# Epoch 16 Batch 2600 Loss 0.1200
# Epoch 16 Batch 2700 Loss 0.0777
# Epoch 16 Batch 2800 Loss 0.1194
# Epoch 16 Batch 2900 Loss 0.1154
# Epoch 16 Batch 3000 Loss 0.0958
# Epoch 16 Batch 3100 Loss 0.1234
# Epoch 16 Batch 3200 Loss 0.1284
# Epoch 16 Batch 3300 Loss 0.1255
# Epoch 16 Batch 3400 Loss 0.0960
# Epoch 16 Batch 3500 Loss 0.1220
# Epoch 16 Batch 3600 Loss 0.1424
# Epoch 16 Batch 3700 Loss 0.1292
# Epoch 16 Loss 0.0962
# Time taken for 1 epoch 1227.822175502777 sec
#
# Epoch 17 Batch 0 Loss 0.0865
# Epoch 17 Batch 100 Loss 0.0779
# Epoch 17 Batch 200 Loss 0.0741
# Epoch 17 Batch 300 Loss 0.0736
# Epoch 17 Batch 400 Loss 0.1090
# Epoch 17 Batch 500 Loss 0.0869
# Epoch 17 Batch 600 Loss 0.0985
# Epoch 17 Batch 700 Loss 0.0987
# Epoch 17 Batch 800 Loss 0.0922
# Epoch 17 Batch 900 Loss 0.0995
# Epoch 17 Batch 1000 Loss 0.0835
# Epoch 17 Batch 1100 Loss 0.0910
# Epoch 17 Batch 1200 Loss 0.0787
# Epoch 17 Batch 1300 Loss 0.0499
# Epoch 17 Batch 1400 Loss 0.1215
# Epoch 17 Batch 1500 Loss 0.0645
# Epoch 17 Batch 1600 Loss 0.0857
# Epoch 17 Batch 1700 Loss 0.1141
# Epoch 17 Batch 1800 Loss 0.0953
# Epoch 17 Batch 1900 Loss 0.1390
# Epoch 17 Batch 2000 Loss 0.0947
# Epoch 17 Batch 2100 Loss 0.1244
# Epoch 17 Batch 2200 Loss 0.1342
# Epoch 17 Batch 2300 Loss 0.0926
# Epoch 17 Batch 2400 Loss 0.1392
# Epoch 17 Batch 2500 Loss 0.1036
# Epoch 17 Batch 2600 Loss 0.1033
# Epoch 17 Batch 2700 Loss 0.1239
# Epoch 17 Batch 2800 Loss 0.1089
# Epoch 17 Batch 2900 Loss 0.1012
# Epoch 17 Batch 3000 Loss 0.1023
# Epoch 17 Batch 3100 Loss 0.1268
# Epoch 17 Batch 3200 Loss 0.0983
# Epoch 17 Batch 3300 Loss 0.1131
# Epoch 17 Batch 3400 Loss 0.1080
# Epoch 17 Batch 3500 Loss 0.1118
# Epoch 17 Batch 3600 Loss 0.1414
# Epoch 17 Batch 3700 Loss 0.0912
# Epoch 17 Loss 0.0971
# Time taken for 1 epoch 1213.394441127777 sec
#
# Epoch 18 Batch 0 Loss 0.1079
# Epoch 18 Batch 100 Loss 0.0695
# Epoch 18 Batch 200 Loss 0.0678
# Epoch 18 Batch 300 Loss 0.0904
# Epoch 18 Batch 400 Loss 0.0538
# Epoch 18 Batch 500 Loss 0.0698
# Epoch 18 Batch 600 Loss 0.0948
# Epoch 18 Batch 700 Loss 0.0680
# Epoch 18 Batch 800 Loss 0.0948
# Epoch 18 Batch 900 Loss 0.0632
# Epoch 18 Batch 1000 Loss 0.0788
# Epoch 18 Batch 1100 Loss 0.0926
# Epoch 18 Batch 1200 Loss 0.0765
# Epoch 18 Batch 1300 Loss 0.0933
# Epoch 18 Batch 1400 Loss 0.0638
# Epoch 18 Batch 1500 Loss 0.1240
# Epoch 18 Batch 1600 Loss 0.0800
# Epoch 18 Batch 1700 Loss 0.0917
# Epoch 18 Batch 1800 Loss 0.1222
# Epoch 18 Batch 1900 Loss 0.0850
# Epoch 18 Batch 2000 Loss 0.0933
# Epoch 18 Batch 2100 Loss 0.0718
# Epoch 18 Batch 2200 Loss 0.1077
# Epoch 18 Batch 2300 Loss 0.0887
# Epoch 18 Batch 2400 Loss 0.0857
# Epoch 18 Batch 2500 Loss 0.0924
# Epoch 18 Batch 2600 Loss 0.1162
# Epoch 18 Batch 2700 Loss 0.1212
# Epoch 18 Batch 2800 Loss 0.1425
# Epoch 18 Batch 2900 Loss 0.1282
# Epoch 18 Batch 3000 Loss 0.1437
# Epoch 18 Batch 3100 Loss 0.1107
# Epoch 18 Batch 3200 Loss 0.1083
# Epoch 18 Batch 3300 Loss 0.1241
# Epoch 18 Batch 3400 Loss 0.1234
# Epoch 18 Batch 3500 Loss 0.1220
# Epoch 18 Batch 3600 Loss 0.1342
# Epoch 18 Batch 3700 Loss 0.1418
# Epoch 18 Loss 0.0959
# Time taken for 1 epoch 1214.3272128105164 sec
#
# Epoch 19 Batch 0 Loss 0.0733
# Epoch 19 Batch 100 Loss 0.0987
# Epoch 19 Batch 200 Loss 0.0949
# Epoch 19 Batch 300 Loss 0.0690
# Epoch 19 Batch 400 Loss 0.0858
# Epoch 19 Batch 500 Loss 0.1045
# Epoch 19 Batch 600 Loss 0.0761
# Epoch 19 Batch 700 Loss 0.0867
# Epoch 19 Batch 800 Loss 0.0824
# Epoch 19 Batch 900 Loss 0.0767
# Epoch 19 Batch 1000 Loss 0.1080
# Epoch 19 Batch 1100 Loss 0.0906
# Epoch 19 Batch 1200 Loss 0.1132
# Epoch 19 Batch 1300 Loss 0.1018
# Epoch 19 Batch 1400 Loss 0.1022
# Epoch 19 Batch 1500 Loss 0.0913
# Epoch 19 Batch 1600 Loss 0.0813
# Epoch 19 Batch 1700 Loss 0.0683
# Epoch 19 Batch 1800 Loss 0.0878
# Epoch 19 Batch 1900 Loss 0.1164
# Epoch 19 Batch 2000 Loss 0.1138
# Epoch 19 Batch 2100 Loss 0.1275
# Epoch 19 Batch 2200 Loss 0.1017
# Epoch 19 Batch 2300 Loss 0.1409
# Epoch 19 Batch 2400 Loss 0.1027
# Epoch 19 Batch 2500 Loss 0.1034
# Epoch 19 Batch 2600 Loss 0.0954
# Epoch 19 Batch 2700 Loss 0.1447
# Epoch 19 Batch 2800 Loss 0.1156
# Epoch 19 Batch 2900 Loss 0.0797
# Epoch 19 Batch 3000 Loss 0.1293
# Epoch 19 Batch 3100 Loss 0.1146
# Epoch 19 Batch 3200 Loss 0.1153
# Epoch 19 Batch 3300 Loss 0.1124
# Epoch 19 Batch 3400 Loss 0.0861
# Epoch 19 Batch 3500 Loss 0.1587
# Epoch 19 Batch 3600 Loss 0.1226
# Epoch 19 Batch 3700 Loss 0.1383
# Epoch 19 Loss 0.0960
# Time taken for 1 epoch 1211.1626591682434 sec
#
# Epoch 20 Batch 0 Loss 0.0803
# Epoch 20 Batch 100 Loss 0.0898
# Epoch 20 Batch 200 Loss 0.0761
# Epoch 20 Batch 300 Loss 0.0582
# Epoch 20 Batch 400 Loss 0.0637
# Epoch 20 Batch 500 Loss 0.1117
# Epoch 20 Batch 600 Loss 0.0621
# Epoch 20 Batch 700 Loss 0.0781
# Epoch 20 Batch 800 Loss 0.0699
# Epoch 20 Batch 900 Loss 0.0920
# Epoch 20 Batch 1000 Loss 0.0699
# Epoch 20 Batch 1100 Loss 0.0701
# Epoch 20 Batch 1200 Loss 0.0822
# Epoch 20 Batch 1300 Loss 0.0769
# Epoch 20 Batch 1400 Loss 0.0848
# Epoch 20 Batch 1500 Loss 0.1251
# Epoch 20 Batch 1600 Loss 0.1232
# Epoch 20 Batch 1700 Loss 0.0723
# Epoch 20 Batch 1800 Loss 0.0912
# Epoch 20 Batch 1900 Loss 0.1256
# Epoch 20 Batch 2000 Loss 0.0846
# Epoch 20 Batch 2100 Loss 0.0838
# Epoch 20 Batch 2200 Loss 0.0683
# Epoch 20 Batch 2300 Loss 0.0891
# Epoch 20 Batch 2400 Loss 0.1055
# Epoch 20 Batch 2500 Loss 0.0826
# Epoch 20 Batch 2600 Loss 0.1017
# Epoch 20 Batch 2700 Loss 0.1171
# Epoch 20 Batch 2800 Loss 0.1146
# Epoch 20 Batch 2900 Loss 0.1102
# Epoch 20 Batch 3000 Loss 0.1285
# Epoch 20 Batch 3100 Loss 0.0827
# Epoch 20 Batch 3200 Loss 0.0812
# Epoch 20 Batch 3300 Loss 0.0934
# Epoch 20 Batch 3400 Loss 0.0682
# Epoch 20 Batch 3500 Loss 0.0680
# Epoch 20 Batch 3600 Loss 0.1253
# Epoch 20 Batch 3700 Loss 0.0963
# Epoch 20 Loss 0.0958
# Time taken for 1 epoch 1210.3577735424042 sec
#
# Epoch 21 Batch 0 Loss 0.0381
# Epoch 21 Batch 100 Loss 0.0703
# Epoch 21 Batch 200 Loss 0.0623
# Epoch 21 Batch 300 Loss 0.0581
# Epoch 21 Batch 400 Loss 0.0856
# Epoch 21 Batch 500 Loss 0.0839
# Epoch 21 Batch 600 Loss 0.0841
# Epoch 21 Batch 700 Loss 0.0630
# Epoch 21 Batch 800 Loss 0.0736
# Epoch 21 Batch 900 Loss 0.0835
# Epoch 21 Batch 1000 Loss 0.0869
# Epoch 21 Batch 1100 Loss 0.0822
# Epoch 21 Batch 1200 Loss 0.0841
# Epoch 21 Batch 1300 Loss 0.1129
# Epoch 21 Batch 1400 Loss 0.1015
# Epoch 21 Batch 1500 Loss 0.0865
# Epoch 21 Batch 1600 Loss 0.0948
# Epoch 21 Batch 1700 Loss 0.0762
# Epoch 21 Batch 1800 Loss 0.1401
# Epoch 21 Batch 1900 Loss 0.1305
# Epoch 21 Batch 2000 Loss 0.0791
# Epoch 21 Batch 2100 Loss 0.0956
# Epoch 21 Batch 2200 Loss 0.0913
# Epoch 21 Batch 2300 Loss 0.0834
# Epoch 21 Batch 2400 Loss 0.1006
# Epoch 21 Batch 2500 Loss 0.0774
# Epoch 21 Batch 2600 Loss 0.1228
# Epoch 21 Batch 2700 Loss 0.0939
# Epoch 21 Batch 2800 Loss 0.0851
# Epoch 21 Batch 2900 Loss 0.0978
# Epoch 21 Batch 3000 Loss 0.1186
# Epoch 21 Batch 3100 Loss 0.1028
# Epoch 21 Batch 3200 Loss 0.1285
# Epoch 21 Batch 3300 Loss 0.0854
# Epoch 21 Batch 3400 Loss 0.1578
# Epoch 21 Batch 3500 Loss 0.1406
# Epoch 21 Batch 3600 Loss 0.1107
# Epoch 21 Batch 3700 Loss 0.1204
# Epoch 21 Loss 0.0954
# Time taken for 1 epoch 1208.1203677654266 sec
#
# Epoch 22 Batch 0 Loss 0.0611
# Epoch 22 Batch 100 Loss 0.0700
# Epoch 22 Batch 200 Loss 0.0853
# Epoch 22 Batch 300 Loss 0.0660
# Epoch 22 Batch 400 Loss 0.0669
# Epoch 22 Batch 500 Loss 0.0727
# Epoch 22 Batch 600 Loss 0.0791
# Epoch 22 Batch 700 Loss 0.0715
# Epoch 22 Batch 800 Loss 0.0854
# Epoch 22 Batch 900 Loss 0.0834
# Epoch 22 Batch 1000 Loss 0.0835
# Epoch 22 Batch 1100 Loss 0.0980
# Epoch 22 Batch 1200 Loss 0.1016
# Epoch 22 Batch 1300 Loss 0.1234
# Epoch 22 Batch 1400 Loss 0.1066
# Epoch 22 Batch 1500 Loss 0.0461
# Epoch 22 Batch 1600 Loss 0.0694
# Epoch 22 Batch 1700 Loss 0.1282
# Epoch 22 Batch 1800 Loss 0.1152
# Epoch 22 Batch 1900 Loss 0.0955
# Epoch 22 Batch 2000 Loss 0.1564
# Epoch 22 Batch 2100 Loss 0.1052
# Epoch 22 Batch 2200 Loss 0.1260
# Epoch 22 Batch 2300 Loss 0.1352
# Epoch 22 Batch 2400 Loss 0.0978
# Epoch 22 Batch 2500 Loss 0.0697
# Epoch 22 Batch 2600 Loss 0.0712
# Epoch 22 Batch 2700 Loss 0.1300
# Epoch 22 Batch 2800 Loss 0.1237
# Epoch 22 Batch 2900 Loss 0.1148
# Epoch 22 Batch 3000 Loss 0.0800
# Epoch 22 Batch 3100 Loss 0.1022
# Epoch 22 Batch 3200 Loss 0.1320
# Epoch 22 Batch 3300 Loss 0.1582
# Epoch 22 Batch 3400 Loss 0.0529
# Epoch 22 Batch 3500 Loss 0.0838
# Epoch 22 Batch 3600 Loss 0.1169
# Epoch 22 Batch 3700 Loss 0.1043
# Epoch 22 Loss 0.0959
# Time taken for 1 epoch 1209.3120787143707 sec
#
# Epoch 23 Batch 0 Loss 0.0721
# Epoch 23 Batch 100 Loss 0.0796
# Epoch 23 Batch 200 Loss 0.0424
# Epoch 23 Batch 300 Loss 0.0762
# Epoch 23 Batch 400 Loss 0.0992
# Epoch 23 Batch 500 Loss 0.0939
# Epoch 23 Batch 600 Loss 0.0952
# Epoch 23 Batch 700 Loss 0.1439
# Epoch 23 Batch 800 Loss 0.1066
# Epoch 23 Batch 900 Loss 0.0572
# Epoch 23 Batch 1000 Loss 0.0750
# Epoch 23 Batch 1100 Loss 0.0811
# Epoch 23 Batch 1200 Loss 0.0971
# Epoch 23 Batch 1300 Loss 0.0646
# Epoch 23 Batch 1400 Loss 0.0767
# Epoch 23 Batch 1500 Loss 0.0850
# Epoch 23 Batch 1600 Loss 0.1084
# Epoch 23 Batch 1700 Loss 0.1436
# Epoch 23 Batch 1800 Loss 0.1010
# Epoch 23 Batch 1900 Loss 0.1737
# Epoch 23 Batch 2000 Loss 0.0994
# Epoch 23 Batch 2100 Loss 0.0933
# Epoch 23 Batch 2200 Loss 0.0814
# Epoch 23 Batch 2300 Loss 0.1088
# Epoch 23 Batch 2400 Loss 0.1022
# Epoch 23 Batch 2500 Loss 0.1047
# Epoch 23 Batch 2600 Loss 0.0942
# Epoch 23 Batch 2700 Loss 0.1080
# Epoch 23 Batch 2800 Loss 0.0936
# Epoch 23 Batch 2900 Loss 0.0855
# Epoch 23 Batch 3000 Loss 0.1154
# Epoch 23 Batch 3100 Loss 0.0990
# Epoch 23 Batch 3200 Loss 0.1187
# Epoch 23 Batch 3300 Loss 0.0895
# Epoch 23 Batch 3400 Loss 0.1197
# Epoch 23 Batch 3500 Loss 0.1553
# Epoch 23 Batch 3600 Loss 0.0801
# Epoch 23 Batch 3700 Loss 0.1315
# Epoch 23 Loss 0.0964
# Time taken for 1 epoch 1208.0063626766205 sec
#
# Epoch 24 Batch 0 Loss 0.0806
# Epoch 24 Batch 100 Loss 0.0872
# Epoch 24 Batch 200 Loss 0.0753
# Epoch 24 Batch 300 Loss 0.0396
# Epoch 24 Batch 400 Loss 0.0960
# Epoch 24 Batch 500 Loss 0.0549
# Epoch 24 Batch 600 Loss 0.0737
# Epoch 24 Batch 700 Loss 0.0810
# Epoch 24 Batch 800 Loss 0.0690
# Epoch 24 Batch 900 Loss 0.0827
# Epoch 24 Batch 1000 Loss 0.0619
# Epoch 24 Batch 1100 Loss 0.0804
# Epoch 24 Batch 1200 Loss 0.0564
# Epoch 24 Batch 1300 Loss 0.1189
# Epoch 24 Batch 1400 Loss 0.0957
# Epoch 24 Batch 1500 Loss 0.1077
# Epoch 24 Batch 1600 Loss 0.0800
# Epoch 24 Batch 1700 Loss 0.1136
# Epoch 24 Batch 1800 Loss 0.0791
# Epoch 24 Batch 1900 Loss 0.0990
# Epoch 24 Batch 2000 Loss 0.0923
# Epoch 24 Batch 2100 Loss 0.1251
# Epoch 24 Batch 2200 Loss 0.0777
# Epoch 24 Batch 2300 Loss 0.0864
# Epoch 24 Batch 2400 Loss 0.1508
# Epoch 24 Batch 2500 Loss 0.0950
# Epoch 24 Batch 2600 Loss 0.0946
# Epoch 24 Batch 2700 Loss 0.1246
# Epoch 24 Batch 2800 Loss 0.1004
# Epoch 24 Batch 2900 Loss 0.1066
# Epoch 24 Batch 3000 Loss 0.0960
# Epoch 24 Batch 3100 Loss 0.1089
# Epoch 24 Batch 3200 Loss 0.1011
# Epoch 24 Batch 3300 Loss 0.1004
# Epoch 24 Batch 3400 Loss 0.1161
# Epoch 24 Batch 3500 Loss 0.1383
# Epoch 24 Batch 3600 Loss 0.1124
# Epoch 24 Batch 3700 Loss 0.1397
# Epoch 24 Loss 0.0966
# Time taken for 1 epoch 1209.3776042461395 sec
#
# Epoch 25 Batch 0 Loss 0.1068
# Epoch 25 Batch 100 Loss 0.0642
# Epoch 25 Batch 200 Loss 0.0561
# Epoch 25 Batch 300 Loss 0.0811
# Epoch 25 Batch 400 Loss 0.0747
# Epoch 25 Batch 500 Loss 0.0680
# Epoch 25 Batch 600 Loss 0.0769
# Epoch 25 Batch 700 Loss 0.0751
# Epoch 25 Batch 800 Loss 0.0858
# Epoch 25 Batch 900 Loss 0.0908
# Epoch 25 Batch 1000 Loss 0.0978
# Epoch 25 Batch 1100 Loss 0.0801
# Epoch 25 Batch 1200 Loss 0.1529
# Epoch 25 Batch 1300 Loss 0.0602
# Epoch 25 Batch 1400 Loss 0.1004
# Epoch 25 Batch 1500 Loss 0.0955
# Epoch 25 Batch 1600 Loss 0.1372
# Epoch 25 Batch 1700 Loss 0.0962
# Epoch 25 Batch 1800 Loss 0.1143
# Epoch 25 Batch 1900 Loss 0.0933
# Epoch 25 Batch 2000 Loss 0.1086
# Epoch 25 Batch 2100 Loss 0.1352
# Epoch 25 Batch 2200 Loss 0.1150
# Epoch 25 Batch 2300 Loss 0.1114
# Epoch 25 Batch 2400 Loss 0.0777
# Epoch 25 Batch 2500 Loss 0.1332
# Epoch 25 Batch 2600 Loss 0.0913
# Epoch 25 Batch 2700 Loss 0.1189
# Epoch 25 Batch 2800 Loss 0.0910
# Epoch 25 Batch 2900 Loss 0.0972
# Epoch 25 Batch 3000 Loss 0.0755
# Epoch 25 Batch 3100 Loss 0.0875
# Epoch 25 Batch 3200 Loss 0.1247
# Epoch 25 Batch 3300 Loss 0.0902
# Epoch 25 Batch 3400 Loss 0.1328
# Epoch 25 Batch 3500 Loss 0.1048
# Epoch 25 Batch 3600 Loss 0.1277
# Epoch 25 Batch 3700 Loss 0.1080
# Epoch 25 Loss 0.0966
# Time taken for 1 epoch 1208.1518807411194 sec
#
# Epoch 26 Batch 0 Loss 0.0648
# Epoch 26 Batch 100 Loss 0.0699
# Epoch 26 Batch 200 Loss 0.0591
# Epoch 26 Batch 300 Loss 0.0491
# Epoch 26 Batch 400 Loss 0.0769
# Epoch 26 Batch 500 Loss 0.0602
# Epoch 26 Batch 600 Loss 0.1242
# Epoch 26 Batch 700 Loss 0.0932
# Epoch 26 Batch 800 Loss 0.0736
# Epoch 26 Batch 900 Loss 0.0882
# Epoch 26 Batch 1000 Loss 0.0503
# Epoch 26 Batch 1100 Loss 0.1067
# Epoch 26 Batch 1200 Loss 0.1007
# Epoch 26 Batch 1300 Loss 0.0668
# Epoch 26 Batch 1400 Loss 0.0937
# Epoch 26 Batch 1500 Loss 0.0951
# Epoch 26 Batch 1600 Loss 0.0878
# Epoch 26 Batch 1700 Loss 0.0708
# Epoch 26 Batch 1800 Loss 0.1330
# Epoch 26 Batch 1900 Loss 0.0947
# Epoch 26 Batch 2000 Loss 0.1664
# Epoch 26 Batch 2100 Loss 0.0909
# Epoch 26 Batch 2200 Loss 0.1367
# Epoch 26 Batch 2300 Loss 0.1381
# Epoch 26 Batch 2400 Loss 0.0893
# Epoch 26 Batch 2500 Loss 0.0596
# Epoch 26 Batch 2600 Loss 0.1467
# Epoch 26 Batch 2700 Loss 0.0933
# Epoch 26 Batch 2800 Loss 0.0960
# Epoch 26 Batch 2900 Loss 0.0719
# Epoch 26 Batch 3000 Loss 0.1173
# Epoch 26 Batch 3100 Loss 0.1340
# Epoch 26 Batch 3200 Loss 0.0977
# Epoch 26 Batch 3300 Loss 0.0760
# Epoch 26 Batch 3400 Loss 0.1175
# Epoch 26 Batch 3500 Loss 0.0930
# Epoch 26 Batch 3600 Loss 0.1134
# Epoch 26 Batch 3700 Loss 0.1062
# Epoch 26 Loss 0.0975
# Time taken for 1 epoch 1209.6322791576385 sec
#
# Epoch 27 Batch 0 Loss 0.0510
# Epoch 27 Batch 100 Loss 0.0945
# Epoch 27 Batch 200 Loss 0.0587
# Epoch 27 Batch 300 Loss 0.0629
# Epoch 27 Batch 400 Loss 0.0831
# Epoch 27 Batch 500 Loss 0.0935
# Epoch 27 Batch 600 Loss 0.0589
# Epoch 27 Batch 700 Loss 0.0728
# Epoch 27 Batch 800 Loss 0.0838
# Epoch 27 Batch 900 Loss 0.0940
# Epoch 27 Batch 1000 Loss 0.1242
# Epoch 27 Batch 1100 Loss 0.0672
# Epoch 27 Batch 1200 Loss 0.0710
# Epoch 27 Batch 1300 Loss 0.0638
# Epoch 27 Batch 1400 Loss 0.1112
# Epoch 27 Batch 1500 Loss 0.1206
# Epoch 27 Batch 1600 Loss 0.0674
# Epoch 27 Batch 1700 Loss 0.1049
# Epoch 27 Batch 1800 Loss 0.0880
# Epoch 27 Batch 1900 Loss 0.0961
# Epoch 27 Batch 2000 Loss 0.0890
# Epoch 27 Batch 2100 Loss 0.1022
# Epoch 27 Batch 2200 Loss 0.1272
# Epoch 27 Batch 2300 Loss 0.1548
# Epoch 27 Batch 2400 Loss 0.0798
# Epoch 27 Batch 2500 Loss 0.1072
# Epoch 27 Batch 2600 Loss 0.0946
# Epoch 27 Batch 2700 Loss 0.1180
# Epoch 27 Batch 2800 Loss 0.1347
# Epoch 27 Batch 2900 Loss 0.1251
# Epoch 27 Batch 3000 Loss 0.0748
# Epoch 27 Batch 3100 Loss 0.1479
# Epoch 27 Batch 3200 Loss 0.0897
# Epoch 27 Batch 3300 Loss 0.1616
# Epoch 27 Batch 3400 Loss 0.1110
# Epoch 27 Batch 3500 Loss 0.1182
# Epoch 27 Batch 3600 Loss 0.0870
# Epoch 27 Batch 3700 Loss 0.1400
# Epoch 27 Loss 0.0979
# Time taken for 1 epoch 1207.9498722553253 sec
#
# Epoch 28 Batch 0 Loss 0.0748
# Epoch 28 Batch 100 Loss 0.0870
# Epoch 28 Batch 200 Loss 0.0843
# Epoch 28 Batch 300 Loss 0.0994
# Epoch 28 Batch 400 Loss 0.1138
# Epoch 28 Batch 500 Loss 0.0499
# Epoch 28 Batch 600 Loss 0.0810
# Epoch 28 Batch 700 Loss 0.1226
# Epoch 28 Batch 800 Loss 0.1066
# Epoch 28 Batch 900 Loss 0.0912
# Epoch 28 Batch 1000 Loss 0.1065
# Epoch 28 Batch 1100 Loss 0.1095
# Epoch 28 Batch 1200 Loss 0.1167
# Epoch 28 Batch 1300 Loss 0.1216
# Epoch 28 Batch 1400 Loss 0.0937
# Epoch 28 Batch 1500 Loss 0.0811
# Epoch 28 Batch 1600 Loss 0.1340
# Epoch 28 Batch 1700 Loss 0.1456
# Epoch 28 Batch 1800 Loss 0.0610
# Epoch 28 Batch 1900 Loss 0.1054
# Epoch 28 Batch 2000 Loss 0.1313
# Epoch 28 Batch 2100 Loss 0.1278
# Epoch 28 Batch 2200 Loss 0.0991
# Epoch 28 Batch 2300 Loss 0.0975
# Epoch 28 Batch 2400 Loss 0.0610
# Epoch 28 Batch 2500 Loss 0.1025
# Epoch 28 Batch 2600 Loss 0.0701
# Epoch 28 Batch 2700 Loss 0.1060
# Epoch 28 Batch 2800 Loss 0.1329
# Epoch 28 Batch 2900 Loss 0.0775
# Epoch 28 Batch 3000 Loss 0.1307
# Epoch 28 Batch 3100 Loss 0.1295
# Epoch 28 Batch 3200 Loss 0.1197
# Epoch 28 Batch 3300 Loss 0.1320
# Epoch 28 Batch 3400 Loss 0.1070
# Epoch 28 Batch 3500 Loss 0.0890
# Epoch 28 Batch 3600 Loss 0.1640
# Epoch 28 Batch 3700 Loss 0.1111
# Epoch 28 Loss 0.0979
# Time taken for 1 epoch 1209.5323722362518 sec
#
# Epoch 29 Batch 0 Loss 0.1016
# Epoch 29 Batch 100 Loss 0.0645
# Epoch 29 Batch 200 Loss 0.0769
# Epoch 29 Batch 300 Loss 0.0783
# Epoch 29 Batch 400 Loss 0.0697
# Epoch 29 Batch 500 Loss 0.0495
# Epoch 29 Batch 600 Loss 0.0703
# Epoch 29 Batch 700 Loss 0.0888
# Epoch 29 Batch 800 Loss 0.1109
# Epoch 29 Batch 900 Loss 0.1441
# Epoch 29 Batch 1000 Loss 0.1065
# Epoch 29 Batch 1100 Loss 0.1245
# Epoch 29 Batch 1200 Loss 0.0756
# Epoch 29 Batch 1300 Loss 0.1500
# Epoch 29 Batch 1400 Loss 0.0877
# Epoch 29 Batch 1500 Loss 0.0911
# Epoch 29 Batch 1600 Loss 0.0816
# Epoch 29 Batch 1700 Loss 0.0919
# Epoch 29 Batch 1800 Loss 0.0976
# Epoch 29 Batch 1900 Loss 0.0781
# Epoch 29 Batch 2000 Loss 0.0919
# Epoch 29 Batch 2100 Loss 0.0821
# Epoch 29 Batch 2200 Loss 0.1027
# Epoch 29 Batch 2300 Loss 0.1137
# Epoch 29 Batch 2400 Loss 0.1282
# Epoch 29 Batch 2500 Loss 0.0867
# Epoch 29 Batch 2600 Loss 0.1238
# Epoch 29 Batch 2700 Loss 0.0951
# Epoch 29 Batch 2800 Loss 0.0963
# Epoch 29 Batch 2900 Loss 0.1432
# Epoch 29 Batch 3000 Loss 0.1256
# Epoch 29 Batch 3100 Loss 0.1145
# Epoch 29 Batch 3200 Loss 0.1150
# Epoch 29 Batch 3300 Loss 0.1181
# Epoch 29 Batch 3400 Loss 0.1081
# Epoch 29 Batch 3500 Loss 0.0906
# Epoch 29 Batch 3600 Loss 0.1078
# Epoch 29 Batch 3700 Loss 0.0932
# Epoch 29 Loss 0.0987
# Time taken for 1 epoch 1208.331111907959 sec
#
# Epoch 30 Batch 0 Loss 0.0921
# Epoch 30 Batch 100 Loss 0.0599
# Epoch 30 Batch 200 Loss 0.0995
# Epoch 30 Batch 300 Loss 0.0782
# Epoch 30 Batch 400 Loss 0.0869
# Epoch 30 Batch 500 Loss 0.1078
# Epoch 30 Batch 600 Loss 0.0538
# Epoch 30 Batch 700 Loss 0.1069
# Epoch 30 Batch 800 Loss 0.1023
# Epoch 30 Batch 900 Loss 0.0910
# Epoch 30 Batch 1000 Loss 0.0559
# Epoch 30 Batch 1100 Loss 0.0929
# Epoch 30 Batch 1200 Loss 0.0903
# Epoch 30 Batch 1300 Loss 0.0609
# Epoch 30 Batch 1400 Loss 0.0954
# Epoch 30 Batch 1500 Loss 0.1225
# Epoch 30 Batch 1600 Loss 0.1114
# Epoch 30 Batch 1700 Loss 0.1093
# Epoch 30 Batch 1800 Loss 0.0886
# Epoch 30 Batch 1900 Loss 0.0916
# Epoch 30 Batch 2000 Loss 0.1084
# Epoch 30 Batch 2100 Loss 0.1050
# Epoch 30 Batch 2200 Loss 0.1043
# Epoch 30 Batch 2300 Loss 0.0790
# Epoch 30 Batch 2400 Loss 0.1352
# Epoch 30 Batch 2500 Loss 0.0984
# Epoch 30 Batch 2600 Loss 0.1185
# Epoch 30 Batch 2700 Loss 0.0929
# Epoch 30 Batch 2800 Loss 0.1477
# Epoch 30 Batch 2900 Loss 0.0803
# Epoch 30 Batch 3000 Loss 0.1358
# Epoch 30 Batch 3100 Loss 0.1038
# Epoch 30 Batch 3200 Loss 0.1442
# Epoch 30 Batch 3300 Loss 0.0930
# Epoch 30 Batch 3400 Loss 0.0856
# Epoch 30 Batch 3500 Loss 0.0820
# Epoch 30 Batch 3600 Loss 0.1518
# Epoch 30 Batch 3700 Loss 0.1002
# Epoch 30 Loss 0.0986
# Time taken for 1 epoch 1210.2322430610657 sec
#
# Epoch 31 Batch 0 Loss 0.1049
# Epoch 31 Batch 100 Loss 0.0982
# Epoch 31 Batch 200 Loss 0.1186
# Epoch 31 Batch 300 Loss 0.0746
# Epoch 31 Batch 400 Loss 0.0611
# Epoch 31 Batch 500 Loss 0.0571
# Epoch 31 Batch 600 Loss 0.0751
# Epoch 31 Batch 700 Loss 0.0844
# Epoch 31 Batch 800 Loss 0.0965
# Epoch 31 Batch 900 Loss 0.1070
# Epoch 31 Batch 1000 Loss 0.0977
# Epoch 31 Batch 1100 Loss 0.1075
# Epoch 31 Batch 1200 Loss 0.0841
# Epoch 31 Batch 1300 Loss 0.0906
# Epoch 31 Batch 1400 Loss 0.1125
# Epoch 31 Batch 1500 Loss 0.0800
# Epoch 31 Batch 1600 Loss 0.0735
# Epoch 31 Batch 1700 Loss 0.0931
# Epoch 31 Batch 1800 Loss 0.0745
# Epoch 31 Batch 1900 Loss 0.1172
# Epoch 31 Batch 2000 Loss 0.1615
# Epoch 31 Batch 2100 Loss 0.1434
# Epoch 31 Batch 2200 Loss 0.1296
# Epoch 31 Batch 2300 Loss 0.1235
# Epoch 31 Batch 2400 Loss 0.0637
# Epoch 31 Batch 2500 Loss 0.0937
# Epoch 31 Batch 2600 Loss 0.1302
# Epoch 31 Batch 2700 Loss 0.0546
# Epoch 31 Batch 2800 Loss 0.1273
# Epoch 31 Batch 2900 Loss 0.1203
# Epoch 31 Batch 3000 Loss 0.1397
# Epoch 31 Batch 3100 Loss 0.1310
# Epoch 31 Batch 3200 Loss 0.1026
# Epoch 31 Batch 3300 Loss 0.0885
# Epoch 31 Batch 3400 Loss 0.1141
# Epoch 31 Batch 3500 Loss 0.1386
# Epoch 31 Batch 3600 Loss 0.1091
# Epoch 31 Batch 3700 Loss 0.0949
# Epoch 31 Loss 0.0999
# Time taken for 1 epoch 1208.1677165031433 sec
#
# Epoch 32 Batch 0 Loss 0.0547
# Epoch 32 Batch 100 Loss 0.1033
# Epoch 32 Batch 200 Loss 0.0754
# Epoch 32 Batch 300 Loss 0.0716
# Epoch 32 Batch 400 Loss 0.0973
# Epoch 32 Batch 500 Loss 0.0874
# Epoch 32 Batch 600 Loss 0.0714
# Epoch 32 Batch 700 Loss 0.0907
# Epoch 32 Batch 800 Loss 0.0814
# Epoch 32 Batch 900 Loss 0.0919
# Epoch 32 Batch 1000 Loss 0.0925
# Epoch 32 Batch 1100 Loss 0.0863
# Epoch 32 Batch 1200 Loss 0.1084
# Epoch 32 Batch 1300 Loss 0.0899
# Epoch 32 Batch 1400 Loss 0.0984
# Epoch 32 Batch 1500 Loss 0.0899
# Epoch 32 Batch 1600 Loss 0.0978
# Epoch 32 Batch 1700 Loss 0.0887
# Epoch 32 Batch 1800 Loss 0.0845
# Epoch 32 Batch 1900 Loss 0.1067
# Epoch 32 Batch 2000 Loss 0.1100
# Epoch 32 Batch 2100 Loss 0.1117
# Epoch 32 Batch 2200 Loss 0.0879
# Epoch 32 Batch 2300 Loss 0.1134
# Epoch 32 Batch 2400 Loss 0.1124
# Epoch 32 Batch 2500 Loss 0.1259
# Epoch 32 Batch 2600 Loss 0.1135
# Epoch 32 Batch 2700 Loss 0.1177
# Epoch 32 Batch 2800 Loss 0.0780
# Epoch 32 Batch 2900 Loss 0.0843
# Epoch 32 Batch 3000 Loss 0.0835
# Epoch 32 Batch 3100 Loss 0.1036
# Epoch 32 Batch 3200 Loss 0.1246
# Epoch 32 Batch 3300 Loss 0.1006
# Epoch 32 Batch 3400 Loss 0.1632
# Epoch 32 Batch 3500 Loss 0.1228
# Epoch 32 Batch 3600 Loss 0.1451
# Epoch 32 Batch 3700 Loss 0.0982
# Epoch 32 Loss 0.1014
# Time taken for 1 epoch 1210.1248097419739 sec
#
# Epoch 33 Batch 0 Loss 0.1271
# Epoch 33 Batch 100 Loss 0.0794
# Epoch 33 Batch 200 Loss 0.0633
# Epoch 33 Batch 300 Loss 0.0821
# Epoch 33 Batch 400 Loss 0.0848
# Epoch 33 Batch 500 Loss 0.0890
# Epoch 33 Batch 600 Loss 0.0784
# Epoch 33 Batch 700 Loss 0.0794
# Epoch 33 Batch 800 Loss 0.0984
# Epoch 33 Batch 900 Loss 0.0962
# Epoch 33 Batch 1000 Loss 0.0864
# Epoch 33 Batch 1100 Loss 0.0553
# Epoch 33 Batch 1200 Loss 0.0878
# Epoch 33 Batch 1300 Loss 0.0654
# Epoch 33 Batch 1400 Loss 0.0972
# Epoch 33 Batch 1500 Loss 0.1186
# Epoch 33 Batch 1600 Loss 0.0990
# Epoch 33 Batch 1700 Loss 0.0838
# Epoch 33 Batch 1800 Loss 0.0841
# Epoch 33 Batch 1900 Loss 0.0942
# Epoch 33 Batch 2000 Loss 0.1136
# Epoch 33 Batch 2100 Loss 0.1152
# Epoch 33 Batch 2200 Loss 0.1617
# Epoch 33 Batch 2300 Loss 0.0902
# Epoch 33 Batch 2400 Loss 0.1374
# Epoch 33 Batch 2500 Loss 0.0700
# Epoch 33 Batch 2600 Loss 0.1093
# Epoch 33 Batch 2700 Loss 0.0887
# Epoch 33 Batch 2800 Loss 0.0850
# Epoch 33 Batch 2900 Loss 0.1685
# Epoch 33 Batch 3000 Loss 0.1273
# Epoch 33 Batch 3100 Loss 0.1425
# Epoch 33 Batch 3200 Loss 0.1356
# Epoch 33 Batch 3300 Loss 0.1368
# Epoch 33 Batch 3400 Loss 0.1244
# Epoch 33 Batch 3500 Loss 0.1061
# Epoch 33 Batch 3600 Loss 0.1328
# Epoch 33 Batch 3700 Loss 0.1283
# Epoch 33 Loss 0.1015
# Time taken for 1 epoch 1207.6635932922363 sec
#
# Epoch 34 Batch 0 Loss 0.0926
# Epoch 34 Batch 100 Loss 0.0717
# Epoch 34 Batch 200 Loss 0.0816
# Epoch 34 Batch 300 Loss 0.0633
# Epoch 34 Batch 400 Loss 0.0951
# Epoch 34 Batch 500 Loss 0.0986
# Epoch 34 Batch 600 Loss 0.1056
# Epoch 34 Batch 700 Loss 0.0628
# Epoch 34 Batch 800 Loss 0.0694
# Epoch 34 Batch 900 Loss 0.0887
# Epoch 34 Batch 1000 Loss 0.0713
# Epoch 34 Batch 1100 Loss 0.0760
# Epoch 34 Batch 1200 Loss 0.0648
# Epoch 34 Batch 1300 Loss 0.0697
# Epoch 34 Batch 1400 Loss 0.0942
# Epoch 34 Batch 1500 Loss 0.0823
# Epoch 34 Batch 1600 Loss 0.0596
# Epoch 34 Batch 1700 Loss 0.0986
# Epoch 34 Batch 1800 Loss 0.1130
# Epoch 34 Batch 1900 Loss 0.1218
# Epoch 34 Batch 2000 Loss 0.1107
# Epoch 34 Batch 2100 Loss 0.1130
# Epoch 34 Batch 2200 Loss 0.1155
# Epoch 34 Batch 2300 Loss 0.1479
# Epoch 34 Batch 2400 Loss 0.1255
# Epoch 34 Batch 2500 Loss 0.0939
# Epoch 34 Batch 2600 Loss 0.0958
# Epoch 34 Batch 2700 Loss 0.1613
# Epoch 34 Batch 2800 Loss 0.1190
# Epoch 34 Batch 2900 Loss 0.0867
# Epoch 34 Batch 3000 Loss 0.1181
# Epoch 34 Batch 3100 Loss 0.0951
# Epoch 34 Batch 3200 Loss 0.0917
# Epoch 34 Batch 3300 Loss 0.1252
# Epoch 34 Batch 3400 Loss 0.0875
# Epoch 34 Batch 3500 Loss 0.1047
# Epoch 34 Batch 3600 Loss 0.1342
# Epoch 34 Batch 3700 Loss 0.1367
# Epoch 34 Loss 0.1027
# Time taken for 1 epoch 1209.2039411067963 sec
#
# Epoch 35 Batch 0 Loss 0.0693
# Epoch 35 Batch 100 Loss 0.0779
# Epoch 35 Batch 200 Loss 0.0711
# Epoch 35 Batch 300 Loss 0.0899
# Epoch 35 Batch 400 Loss 0.1096
# Epoch 35 Batch 500 Loss 0.0749
# Epoch 35 Batch 600 Loss 0.0822
# Epoch 35 Batch 700 Loss 0.0726
# Epoch 35 Batch 800 Loss 0.1171
# Epoch 35 Batch 900 Loss 0.1149
# Epoch 35 Batch 1000 Loss 0.0961
# Epoch 35 Batch 1100 Loss 0.1021
# Epoch 35 Batch 1200 Loss 0.0863
# Epoch 35 Batch 1300 Loss 0.1074
# Epoch 35 Batch 1400 Loss 0.1201
# Epoch 35 Batch 1500 Loss 0.1027
# Epoch 35 Batch 1600 Loss 0.0841
# Epoch 35 Batch 1700 Loss 0.1119
# Epoch 35 Batch 1800 Loss 0.0771
# Epoch 35 Batch 1900 Loss 0.0433
# Epoch 35 Batch 2000 Loss 0.0993
# Epoch 35 Batch 2100 Loss 0.1166
# Epoch 35 Batch 2200 Loss 0.0855
# Epoch 35 Batch 2300 Loss 0.1356
# Epoch 35 Batch 2400 Loss 0.1305
# Epoch 35 Batch 2500 Loss 0.1035
# Epoch 35 Batch 2600 Loss 0.1176
# Epoch 35 Batch 2700 Loss 0.1411
# Epoch 35 Batch 2800 Loss 0.1561
# Epoch 35 Batch 2900 Loss 0.1034
# Epoch 35 Batch 3000 Loss 0.1247
# Epoch 35 Batch 3100 Loss 0.0939
# Epoch 35 Batch 3200 Loss 0.1118
# Epoch 35 Batch 3300 Loss 0.1018
# Epoch 35 Batch 3400 Loss 0.0941
# Epoch 35 Batch 3500 Loss 0.1323
# Epoch 35 Batch 3600 Loss 0.1205
# Epoch 35 Batch 3700 Loss 0.1192
# Epoch 35 Loss 0.1033
# Time taken for 1 epoch 1207.8362879753113 sec
#
# Epoch 36 Batch 0 Loss 0.0952
# Epoch 36 Batch 100 Loss 0.0657
# Epoch 36 Batch 200 Loss 0.0586
# Epoch 36 Batch 300 Loss 0.0632
# Epoch 36 Batch 400 Loss 0.1230
# Epoch 36 Batch 500 Loss 0.0687
# Epoch 36 Batch 600 Loss 0.0598
# Epoch 36 Batch 700 Loss 0.0816
# Epoch 36 Batch 800 Loss 0.0836
# Epoch 36 Batch 900 Loss 0.0623
# Epoch 36 Batch 1000 Loss 0.1071
# Epoch 36 Batch 1100 Loss 0.0671
# Epoch 36 Batch 1200 Loss 0.0735
# Epoch 36 Batch 1300 Loss 0.1194
# Epoch 36 Batch 1400 Loss 0.0443
# Epoch 36 Batch 1500 Loss 0.0504
# Epoch 36 Batch 1600 Loss 0.0987
# Epoch 36 Batch 1700 Loss 0.0867
# Epoch 36 Batch 1800 Loss 0.1092
# Epoch 36 Batch 1900 Loss 0.0974
# Epoch 36 Batch 2000 Loss 0.1123
# Epoch 36 Batch 2100 Loss 0.0922
# Epoch 36 Batch 2200 Loss 0.1405
# Epoch 36 Batch 2300 Loss 0.1125
# Epoch 36 Batch 2400 Loss 0.1205
# Epoch 36 Batch 2500 Loss 0.1082
# Epoch 36 Batch 2600 Loss 0.1037
# Epoch 36 Batch 2700 Loss 0.1063
# Epoch 36 Batch 2800 Loss 0.1225
# Epoch 36 Batch 2900 Loss 0.1311
# Epoch 36 Batch 3000 Loss 0.0782
# Epoch 36 Batch 3100 Loss 0.0984
# Epoch 36 Batch 3200 Loss 0.1113
# Epoch 36 Batch 3300 Loss 0.1398
# Epoch 36 Batch 3400 Loss 0.1424
# Epoch 36 Batch 3500 Loss 0.1080
# Epoch 36 Batch 3600 Loss 0.1084
# Epoch 36 Batch 3700 Loss 0.1198
# Epoch 36 Loss 0.1035
# Time taken for 1 epoch 1208.9836518764496 sec
#
# Epoch 37 Batch 0 Loss 0.0823
# Epoch 37 Batch 100 Loss 0.0999
# Epoch 37 Batch 200 Loss 0.0924
# Epoch 37 Batch 300 Loss 0.0719
# Epoch 37 Batch 400 Loss 0.0760
# Epoch 37 Batch 500 Loss 0.1016
# Epoch 37 Batch 600 Loss 0.0658
# Epoch 37 Batch 700 Loss 0.0974
# Epoch 37 Batch 800 Loss 0.0987
# Epoch 37 Batch 900 Loss 0.1166
# Epoch 37 Batch 1000 Loss 0.0920
# Epoch 37 Batch 1100 Loss 0.0848
# Epoch 37 Batch 1200 Loss 0.1244
# Epoch 37 Batch 1300 Loss 0.1595
# Epoch 37 Batch 1400 Loss 0.0983
# Epoch 37 Batch 1500 Loss 0.1392
# Epoch 37 Batch 1600 Loss 0.1130
# Epoch 37 Batch 1700 Loss 0.0915
# Epoch 37 Batch 1800 Loss 0.0910
# Epoch 37 Batch 1900 Loss 0.1400
# Epoch 37 Batch 2000 Loss 0.1270
# Epoch 37 Batch 2100 Loss 0.0820
# Epoch 37 Batch 2200 Loss 0.1504
# Epoch 37 Batch 2300 Loss 0.0686
# Epoch 37 Batch 2400 Loss 0.1324
# Epoch 37 Batch 2500 Loss 0.1556
# Epoch 37 Batch 2600 Loss 0.1350
# Epoch 37 Batch 2700 Loss 0.0887
# Epoch 37 Batch 2800 Loss 0.1046
# Epoch 37 Batch 2900 Loss 0.1071
# Epoch 37 Batch 3000 Loss 0.1489
# Epoch 37 Batch 3100 Loss 0.1452
# Epoch 37 Batch 3200 Loss 0.1846
# Epoch 37 Batch 3300 Loss 0.1059
# Epoch 37 Batch 3400 Loss 0.0720
# Epoch 37 Batch 3500 Loss 0.1246
# Epoch 37 Batch 3600 Loss 0.1228
# Epoch 37 Batch 3700 Loss 0.1344
# Epoch 37 Loss 0.1048
# Time taken for 1 epoch 1207.8932197093964 sec
#
# Epoch 38 Batch 0 Loss 0.0915
# Epoch 38 Batch 100 Loss 0.0635
# Epoch 38 Batch 200 Loss 0.0900
# Epoch 38 Batch 300 Loss 0.1094
# Epoch 38 Batch 400 Loss 0.0705
# Epoch 38 Batch 500 Loss 0.0762
# Epoch 38 Batch 600 Loss 0.0678
# Epoch 38 Batch 700 Loss 0.0883
# Epoch 38 Batch 800 Loss 0.0546
# Epoch 38 Batch 900 Loss 0.1042
# Epoch 38 Batch 1000 Loss 0.0567
# Epoch 38 Batch 1100 Loss 0.0836
# Epoch 38 Batch 1200 Loss 0.1116
# Epoch 38 Batch 1300 Loss 0.1051
# Epoch 38 Batch 1400 Loss 0.1089
# Epoch 38 Batch 1500 Loss 0.0726
# Epoch 38 Batch 1600 Loss 0.1107
# Epoch 38 Batch 1700 Loss 0.0807
# Epoch 38 Batch 1800 Loss 0.1127
# Epoch 38 Batch 1900 Loss 0.0729
# Epoch 38 Batch 2000 Loss 0.1358
# Epoch 38 Batch 2100 Loss 0.0922
# Epoch 38 Batch 2200 Loss 0.1122
# Epoch 38 Batch 2300 Loss 0.0796
# Epoch 38 Batch 2400 Loss 0.0965
# Epoch 38 Batch 2500 Loss 0.1073
# Epoch 38 Batch 2600 Loss 0.1356
# Epoch 38 Batch 2700 Loss 0.1007
# Epoch 38 Batch 2800 Loss 0.1374
# Epoch 38 Batch 2900 Loss 0.1276
# Epoch 38 Batch 3000 Loss 0.1082
# Epoch 38 Batch 3100 Loss 0.0949
# Epoch 38 Batch 3200 Loss 0.1578
# Epoch 38 Batch 3300 Loss 0.1182
# Epoch 38 Batch 3400 Loss 0.1235
# Epoch 38 Batch 3500 Loss 0.0963
# Epoch 38 Batch 3600 Loss 0.1230
# Epoch 38 Batch 3700 Loss 0.1158
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\util.py in save(self, file_prefix, options)
#    2175     else:
#    2176       checkpoint_number = assign_op.numpy()
# -> 2177     file_path = self.write("%s-%d" % (file_prefix, checkpoint_number),
#    2178                            options=options)
#    2179     checkpoint_management.update_checkpoint_state_internal(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\util.py in write(self, file_prefix, options)
#    2072     start_time = time.time()
#    2073     options = options or checkpoint_options.CheckpointOptions()
# -> 2074     output = self._saver.save(file_prefix=file_prefix, options=options)
#    2075     end_time = time.time()
#    2076
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session, options)
#    1238
#    1239     file_io.recursive_create_dir(os.path.dirname(file_prefix))
# -> 1240     save_path, new_feed_additions = self._save_cached_when_graph_building(
#    1241         file_prefix_tensor, object_graph_tensor, options)
#    1242     if new_feed_additions:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor, options)
#    1184         or context.executing_eagerly() or ops.inside_function()):
#    1185       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1186       save_op = saver.save(file_prefix, options=options)
#    1187       with ops.device("/cpu:0"):
#    1188         with ops.control_dependencies([save_op]):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in save(self, file_prefix, options)
#     298       tf_function_save()
#     299     else:
# --> 300       return save_fn()
#     301
#     302   def restore(self, file_prefix, options=None):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in save_fn()
#     272           # initial read operations should be placed on the SaveableObject's
#     273           # device.
# --> 274           sharded_saves.append(saver.save(shard_prefix, options))
#     275
#     276       with ops.control_dependencies(sharded_saves):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in save(self, file_prefix, options)
#      81     save_device = options.experimental_io_device or "cpu:0"
#      82     with ops.device(save_device):
# ---> 83       return io_ops.save_v2(file_prefix, tensor_names, tensor_slices, tensors)
#      84
#      85   def restore(self, file_prefix, options=None):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py in save_v2(prefix, tensor_names, shape_and_slices, tensors, name)
#    1704       pass
#    1705     try:
# -> 1706       return save_v2_eager_fallback(
#    1707           prefix, tensor_names, shape_and_slices, tensors, name=name,
#    1708           ctx=_ctx)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py in save_v2_eager_fallback(prefix, tensor_names, shape_and_slices, tensors, name, ctx)
#    1725   _inputs_flat = [prefix, tensor_names, shape_and_slices] + list(tensors)
#    1726   _attrs = ("dtypes", _attr_dtypes)
# -> 1727   _result = _execute.execute(b"SaveV2", 0, inputs=_inputs_flat, attrs=_attrs,
#    1728                              ctx=ctx, name=name)
#    1729   _result = None
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcd in position 133: invalid continuation byte

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %% [markdown]
# ## Тестирование

# %%
# Тестируем

test_texts = ['Здесь хорошо.', 'Я не смогу поехать.', 'Когда нам воду дадут?',
              'Я делаю домашнюю работу.', 'Люби Родину, мать твою.',
              'Перевод без механизма внимания SEQ2SEQ модель', 'Выберите постельное белье по вашим параметрам.',
              ]

for text in test_texts:
    translate(text)
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's good . <end>
# Input: <start> я не смогу поехать . <end>
# Predicted translation: i can't go . <end>
# Input: <start> когда нам воду дадут ? <end>
# Predicted translation: when will we give up the tv ? <end>
# Input: <start> я делаю домашнюю работу . <end>
# Predicted translation: i'm doing my homework . <end>
# Input: <start> люби родину , мать твою . <end>
# Predicted translation: love your mentioned to your mother . <end>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-0c8ecd555aeb> in <module>
#       7
#       8 for text in test_texts:
# ----> 9     translate(text)
#
# <ipython-input-42-d01480530bee> in translate(sentence)
#       1 def translate(sentence):
# ----> 2   result, sentence = evaluate(sentence)
#       3
#       4   print('Input: %s' % (sentence))
#       5   print('Predicted translation: {}'.format(result))
#
# <ipython-input-41-baaeed8448d5> in evaluate(sentence)
#       4   sentence = preprocess_sentence(sentence)
#       5
# ----> 6   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7   inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                          maxlen=max_length_inp,
#
# <ipython-input-41-baaeed8448d5> in <listcomp>(.0)
#       4   sentence = preprocess_sentence(sentence)
#       5
# ----> 6   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7   inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                          maxlen=max_length_inp,
#
# KeyError: 'механизма'
